# %%
import PyPDF2

def extrair_texto_de_pdf(caminho_do_pdf):
    # Abrindo o arquivo PDF em modo binário
    with open(caminho_do_pdf, 'rb') as arquivo:
        leitor_pdf = PyPDF2.PdfReader(arquivo)
        num_paginas = len(leitor_pdf.pages)

        # Lendo cada página e extraindo o texto
        texto_completo = ''
        for pagina in range(num_paginas):
            texto_pagina = leitor_pdf.pages[pagina].extract_text()
            texto_completo += texto_pagina

    return texto_completo

# Exemplo de uso
caminho_do_pdf = r'C:\Users\pytho\Downloads\Hemograma_Completo.pdf'  # Substitua pelo caminho do seu arquivo PDF
texto_extraido = extrair_texto_de_pdf(caminho_do_pdf)
# print(texto_extraido)

# %%
import re

def extrair_dados_hemograma(texto):
    dados = {}

    # Extrair os valores do hemograma
    padroes = {
        'Eritrócitos': r'Eritrócitos[^\d]+(\d+,\d+)',
        'Hemoglobina': r'Hemoglobina[^\d]+(\d+,\d+)',
        'Hematócrito': r'Hematócrito[^\d]+(\d+,\d+)',
        'V.C.M.': r'V.C.M.[^\d]+(\d+,\d+)',
        'H.C.M.': r'H.C.M.[^\d]+(\d+,\d+)',
        'C.H.C.M.': r'C.H.C.M.[^\d]+(\d+,\d+)',
        'RDW (Indice de Ansiocitose)': r'RDW \(Indice de Ansiocitose\)[^\d]+(\d+,\d+)',
        'Leucócitos': r'Leucócitos[^\d]+(\d+,\d+)',
        'Mielócitos': r'Mielócitos[^\d]+(\d+,\d+)',
        'Metamielócitos': r'Metamielócitos[^\d]+(\d+,\d+)',
        'Bastonetes': r'Bastonetes[^\d]+(\d+,\d+)',
        'Segmentados': r'Segmentados[^\d]+(\d+,\d+)',
        'Eosinófilos': r'Eosinófilos[^\d]+(\d+,\d+)',
        'Basófilos': r'Basófilos[^\d]+(\d+,\d+)',
        'Linfócitos Típicos': r'Linfócitos Típicos[^\d]+(\d+,\d+)',
        'Linfócitos Atípicos.': r'Linfócitos Atípicos\.[^\d]+(\d+,\d+)',
        'Monócitos': r'Monócitos[^\d]+(\d+,\d+)',
        'Plaquetas': r'Plaquetas[^\d]+(\d+,\d+)',
    }

    for chave, padrao in padroes.items():
        match = re.search(padrao, texto)
        if match:
            dados[chave] = match.group(1).replace(',', '.')

    return dados

# Exemplo de uso
texto_extrai = texto_extraido
dados_hemograma = extrair_dados_hemograma(texto_extrai)
# print(dados_hemograma)

# %%
# Assumindo que o texto foi extraído corretamente e os dados foram extraídos
# dados_hemograma = {'Hemoglobina': 14.5, 'Leucocitos': 6.5, 'Plaquetas': 190, ...}

import pandas as pd
# Convertendo dados extraídos em DataFrame
dados_extraidos_df = pd.DataFrame([dados_hemograma])


print(dados_extraidos_df)
# Out:
#   Eritrócitos Hemoglobina Hematócrito V.C.M. H.C.M. C.H.C.M. Mielócitos
# 0        4.24       12.30        37.3   88.0   29.0     33.0       0.00  \
#
#   Metamielócitos Bastonetes Segmentados Eosinófilos Basófilos
# 0           0.00       0.00       64.30        1.40      0.50  \
#
#   Linfócitos Típicos Monócitos
# 0              24.40      9.40
# O Kernel falhou ao executar o código na célula atual ou em uma célula anterior. Examine o código nas células para identificar uma possível causa da falha. Clique <a href="https://aka.ms/vscodeJupyterKernelCrash">aqui</a> para obter mais informações. Consulte o <a href='command:jupyter.viewOutput'>log</a> do Jupyter para obter mais detalhes.

# %%
padroes = {
    'Eritrócitos': "4.2 - 5.9 milhões/μL (homens), 3.8 - 5.2 milhões/μL (mulheres)",
    'Hemoglobina': "13.8 - 17.2 g/dL (homens), 12.1 - 15.1 g/dL (mulheres)",
    'Hematócrito': "40.7 - 50.3% (homens), 36.1 - 44.3% (mulheres)",
    'V.C.M.': "80 - 100 fL",
    'H.C.M.': "27 - 34 pg",
    'C.H.C.M.': "32 - 36 g/dL",
    'RDW (Indice de Ansiocitose)': "11.5 - 14.5%",
    'Leucócitos': "3.5 - 10.5 mil/μL",
    'Mielócitos': "0% (não normalmente presentes)",
    'Metamielócitos': "0% (não normalmente presentes)",
    'Bastonetes': "0 - 500/μL",
    'Segmentados': "1800 - 7000/μL",
    'Eosinófilos': "0 - 450/μL",
    'Basófilos': "0 - 200/μL",
    'Linfócitos Típicos': "1000 - 4800/μL",
    'Linfócitos Atípicos.': "0% (não normalmente presentes)",
    'Monócitos': "200 - 950/μL",
    'Plaquetas': "150.000 - 450.000/μL",
}

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Substitua 'dados_hemograma' pelos valores extraídos do PDF


# Valores de referência
valores_referencia = {
    'Eritrócitos': "4.2 - 5.9 milhões/μL (homens), 3.8 - 5.2 milhões/μL (mulheres)",
    'Hemoglobina': "13.8 - 17.2 g/dL (homens), 12.1 - 15.1 g/dL (mulheres)",
    'Hematócrito': "40.7 - 50.3% (homens), 36.1 - 44.3% (mulheres)",
    'V.C.M.': "80 - 100 fL",
    'H.C.M.': "27 - 34 pg",
    'C.H.C.M.': "32 - 36 g/dL",
    'RDW (Indice de Ansiocitose)': "11.5 - 14.5%",
    'Leucócitos': "3.5 - 10.5 mil/μL",
    'Mielócitos': "0% (não normalmente presentes)",
    'Metamielócitos': "0% (não normalmente presentes)",
    'Bastonetes': "0 - 500/μL",
    'Segmentados': "1800 - 7000/μL",
    'Eosinófilos': "0 - 450/μL",
    'Basófilos': "0 - 200/μL",
    'Linfócitos Típicos': "1000 - 4800/μL",
    'Linfócitos Atípicos.': "0% (não normalmente presentes)",
    'Monócitos': "200 - 950/μL",
    'Plaquetas': "150.000 - 450.000/μL",
}


# Preparando os DataFrames
df_valores_referencia = pd.DataFrame(list(valores_referencia.items()), columns=['Parâmetro', 'Valor Médio'])
df_dados_paciente = pd.DataFrame(list(dados_hemograma.items()), columns=['Parâmetro', 'Valor do Paciente'])

# Mesclando os DataFrames para comparação
df_comparativo = pd.merge(df_valores_referencia, df_dados_paciente, on='Parâmetro')
df_comparativo['Diferença'] = df_comparativo['Valor do Paciente'] - df_comparativo['Valor Médio']

# Número de parâmetros para os gráficos
num_parametros = len(df_comparativo)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
index = np.arange(num_parametros)
bar_width = 0.35

ax.bar(index, df_comparativo['Valor Médio'], bar_width, label='Valor Médio (Referência)')
ax.bar(index + bar_width, df_comparativo['Valor do Paciente'], bar_width, label='Valor do Paciente')

ax.set_xlabel('Parâmetros')
ax.set_ylabel('Valores')
ax.set_title('Comparação de Valores Hemograma: Lado a Lado')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(df_comparativo['Parâmetro'], rotation=45, ha='right')
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.bar(df_comparativo['Parâmetro'], df_comparativo['Valor Médio'], label='Valor Médio (Referência)')
ax.bar(df_comparativo['Parâmetro'], df_comparativo['Diferença'], bottom=df_comparativo['Valor Médio'], label='Diferença (Paciente - Média)')

ax.set_ylabel('Valores')
ax.set_title('Comparação de Valores Hemograma: Empilhado')
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(df_comparativo['Parâmetro'], df_comparativo['Valor Médio'], label='Valor Médio (Referência)', marker='o')
ax.plot(df_comparativo['Parâmetro'], df_comparativo['Valor do Paciente'], label='Valor do Paciente', marker='x')

ax.set_ylabel('Valores')
ax.set_title('Comparação de Valores Hemograma: Linhas')
ax.legend()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.scatter(df_comparativo['Valor Médio'], df_comparativo['Valor do Paciente'])

ax.set_xlabel('Valor Médio (Referência)')
ax.set_ylabel('Valor do Paciente')
ax.set_title('Comparação de Valores Hemograma: Dispersão')

plt.show()

# %%
categorias = df_comparativo['Parâmetro'].tolist() + [df_comparativo['Parâmetro'][0]]
valores_ref = df_comparativo['Valor Médio'].tolist() + [df_comparativo['Valor Médio'][0]]
valores_paciente = df_comparativo['Valor do Paciente'].tolist() + [df_comparativo['Valor do Paciente'][0]]

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

ax.plot(categorias, valores_ref, label='Valor Médio (Referência)')
ax.fill(categorias, valores_ref, alpha=0.1)
ax.plot(categorias, valores_paciente, label='Valor do Paciente')
ax.fill(categorias, valores_paciente, alpha=0.1)

ax.set_title('Comparação de Valores Hemograma: Radar')
ax.legend(loc='upper right')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Supondo que 'df_comparativo' é o DataFrame que contém os dados do hemograma do paciente e os valores médios de referência
# Certifique-se de que este DataFrame esteja preparado corretamente com as colunas 'Parâmetro', 'Valor Médio' e 'Valor do Paciente'

# Número de parâmetros para os gráficos
num_parametros = len(df_comparativo)

# Gráfico de Barras Lado a Lado
fig, ax = plt.subplots(figsize=(10, 8))
index = np.arange(num_parametros)
bar_width = 0.35

ax.bar(index, df_comparativo['Valor Médio'], bar_width, label='Valor Médio (Referência)')
ax.bar(index + bar_width, df_comparativo['Valor do Paciente'], bar_width, label='Valor do Paciente')

ax.set_xlabel('Parâmetros')
ax.set_ylabel('Valores')
ax.set_title('Comparação de Valores Hemograma: Lado a Lado')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(df_comparativo['Parâmetro'], rotation=45, ha='right')
ax.legend()

plt.show()

# Gráfico de Barras Empilhadas
fig, ax = plt.subplots(figsize=(10, 8))

ax.bar(df_comparativo['Parâmetro'], df_comparativo['Valor Médio'], label='Valor Médio (Referência)')
ax.bar(df_comparativo['Parâmetro'], df_comparativo['Diferença'], bottom=df_comparativo['Valor Médio'], label='Diferença (Paciente - Média)')

ax.set_ylabel('Valores')
ax.set_title('Comparação de Valores Hemograma: Empilhado')
ax.legend()

plt.show()

# Gráfico de Linhas
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(df_comparativo['Parâmetro'], df_comparativo['Valor Médio'], label='Valor Médio (Referência)', marker='o')
ax.plot(df_comparativo['Parâmetro'], df_comparativo['Valor do Paciente'], label='Valor do Paciente', marker='x')

ax.set_ylabel('Valores')
ax.set_title('Comparação de Valores Hemograma: Linhas')
ax.legend()

plt.show()

# Gráfico de Dispersão
fig, ax = plt.subplots(figsize=(10, 8))

ax.scatter(df_comparativo['Valor Médio'], df_comparativo['Valor do Paciente'])

ax.set_xlabel('Valor Médio (Referência)')
ax.set_ylabel('Valor do Paciente')
ax.set_title('Comparação de Valores Hemograma: Dispersão')

plt.show()

# Gráfico de Radar
categorias = df_comparativo['Parâmetro'].tolist() + [df_comparativo['Parâmetro'][0]]
valores_ref = df_comparativo['Valor Médio'].tolist() + [df_comparativo['Valor Médio'][0]]
valores_paciente = df_comparativo['Valor do Paciente'].tolist() + [df_comparativo['Valor do Paciente'][0]]

fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

ax.plot(categorias, valores_ref, label='Valor Médio (Referência)')
ax.fill(categorias, valores_ref, alpha=0.1)
ax.plot(categorias, valores_paciente, label='Valor do Paciente')
ax.fill(categorias, valores_paciente, alpha=0.1)

ax.set_title('Comparação de Valores Hemograma: Radar')
ax.legend(loc='upper right')

plt.show()

# %%
from sqlalchemy import create_engine, Column, Integer, String, Date, ForeignKey, TIMESTAMP, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker


# Conectar ao banco de dados Oracle
engine = create_engine("oracle+cx_oracle://rm98370:140602@oracle.fiap.com.br:1521/orcl")

Session = sessionmaker(bind=engine)
session = Session()
Base = declarative_base()

class Consulta(Base):
    __tablename__ = 'consulta'
    __table_args__ = {'autoload': True, 'autoload_with': engine}


    # Adicionar outras colunas conforme necessário

# CRUD Operations

# Create
def create_consulta(data_consulta, horario_consulta, paciente_id, id_prediagnostico, medico_id):
    nova_consulta = Consulta(
        data_consulta=data_consulta, 
        horario_consulta=horario_consulta, 
        paciente_id=paciente_id, 
        id_prediagnostico=id_prediagnostico, 
        medico_id=medico_id
    )
    session.add(nova_consulta)
    session.commit()

# Read
def get_consulta_by_id(consulta_id):
    return session.query(Consulta).filter(Consulta.id == consulta_id).first()

# Update
def update_consulta(consulta_id, **kwargs):
    consulta = session.query(Consulta).filter(Consulta.id == consulta_id).first()
    for key, value in kwargs.items():
        setattr(consulta, key, value)
    session.commit()

# Delete
def delete_consulta(consulta_id):
    consulta = session.query(Consulta).filter(Consulta.id == consulta_id).first()
    session.delete(consulta)
    session.commit()

# Lembre-se de criar as tabelas no banco de dados
Base.metadata.create_all(engine)


from datetime import datetime

# Função para adicionar uma nova consulta
def adicionar_consulta():
    nova_consulta = Consulta(
        id=1,
        data_consulta=datetime.strptime('2023-11-22', '%Y-%m-%d').date(),
        horario_consulta=datetime.strptime('2023-11-22 09:00:00', '%Y-%m-%d %H:%M:%S'),
        paciente_id=1,
        id_prediagnostico=1,
        medico_id=1
    )
    session.add(nova_consulta)
    session.commit()
    print("Consulta adicionada com sucesso.")

# Função para buscar uma consulta pelo ID
def buscar_consulta(consulta_id):
    consulta = session.query(Consulta).filter(Consulta.id == consulta_id).first()
    if consulta:
        print(f"Consulta encontrada: {consulta.id}, {consulta.data_consulta}, {consulta.horario_consulta}")
    else:
        print("Consulta não encontrada.")

# Função para atualizar uma consulta
def atualizar_consulta(consulta_id, novo_horario):
    consulta = session.query(Consulta).filter(Consulta.id == consulta_id).first()
    if consulta:
        consulta.horario_consulta = novo_horario
        session.commit()
        print("Consulta atualizada com sucesso.")
    else:
        print("Consulta não encontrada para atualização.")

# Função para deletar uma consulta
def deletar_consulta(consulta_id):
    consulta = session.query(Consulta).filter(Consulta.id == consulta_id).first()
    if consulta:
        session.delete(consulta)
        session.commit()
        print("Consulta deletada com sucesso.")
    else:
        print("Consulta não encontrada para deletar.")

# Testando as funções
adicionar_consulta()
buscar_consulta(1)
atualizar_consulta(1, datetime.strptime('2023-11-22 10:30:00', '%Y-%m-%d %H:%M:%S'))
buscar_consulta(1)
deletar_consulta(1)
buscar_consulta(1)
# Out:
# C:\Users\pytho\AppData\Local\Temp\ipykernel_5412\2348204356.py:11: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()
# Exception ignored in: <function _ConnectionRecord.checkout.<locals>.<lambda> at 0x000001FB49BF69D0>
# Traceback (most recent call last):
#   File "c:\Users\pytho\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py", line 732, in <lambda>
#     lambda ref: _finalize_fairy(
#   File "c:\Users\pytho\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\pool\base.py", line 988, in _finalize_fairy
#     fairy._reset(
# KeyboardInterrupt:
# ...
